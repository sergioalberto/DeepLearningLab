# %% [markdown]
# # Exploring TestRail data
# **Import pandas and read the files**

# %%
import pandas as pd

# %%
df = pd.read_csv('e2e_regression_qa_long.csv')

# %% [markdown]
# **Exporing the Dataframe**

# %%
df.head(10)
# Out:
#          ID                                              Title  Assigned To  \
# 0  T4470528                   I can navigate to a CZ dashboard          NaN
# 1  T4470529                    I can search for a device in CZ          NaN
# 2  T4470530           I can view components for a given device          NaN
# 3  T4470531  I can find a device in CZ and see a smartview ...          NaN
# 4  T4470532  Verify that Collection Zones display the Added...          NaN
# 5  T4470533  Verify that Collection Zones display their Exp...          NaN
# 6  T4479104  Verify that Collection Zones display a Valid Name          NaN
# 7  T4506520  Verify browser back button work navigating bac...          NaN
# 8  T4470534  Verify that a User is able to open the 'Help a...          NaN
# 9  T4470535  Verify that Help links open Confluence help se...          NaN
#
#     Case ID                                            Comment  \
# 0  C4930754                                                NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114 entries, 0 to 113
# Data columns (total 31 columns):
# ID                                 114 non-null object
# Title                              114 non-null object
# Assigned To                        0 non-null float64
# Case ID                            114 non-null object
# Comment                            20 non-null object
# Cucumber feature                   0 non-null float64
# Defects                            18 non-null object
# Elapsed                            114 non-null object
# Estimate                           0 non-null float64
# In Progress                        0 non-null float64
# Is this test automatable?          114 non-null object
# Nightwatch feature                 114 non-null object
# Number of Features (Complexity)    114 non-null int64
# Owner                              27 non-null object
# Plan                               114 non-null object
# ...

# %%
len(df.index)
# Out:
# 114

# %%
len(df.columns)
# Out:
# 31

# %%
df = df[["Title", "Case ID", "Nightwatch feature", "Defects", "Elapsed", "Section", "Status.1", "Summary", "Tested On", "Owner", "References"]]

# %% [markdown]
# **Test cases results**

# %%
df[(df["Status.1"] == "Passed")]["Status.1"].count()
# Out:
# 94

# %%
df[(df["Status.1"] == "Failed")]["Status.1"].count()
# Out:
# 20

# %% [markdown]
# **How many defects?**

# %%
df["Defects"].count()
# Out:
# 18

# %%
df[df["Defects"].notnull()]["Defects"]
# Out:
# 17               ZING-2881
# 18               ZING-1429
# 20               ZING-2798
# 21               ZING-1429
# 22               ZING-1429
# 26               ZING-1429
# 28               ZING-2798
# 29               ZING-1429
# 31               ZING-1505
# 32               ZING-1505
# 33               ZING-1505
# 53               ZING-1505
# 54               ZING-1505
# 55    ZING-1505, ZING-2467
# 56    ZING-1505, ZING-2467
# 60               ZING-2655
# 65               ZING-2655
# 71               ZING-2655
# Name: Defects, dtype: object

# %% [markdown]
# **See the sections**

# %%
section_grouped = df.groupby(["Section"])
section_grouped.count()['Title']
# Out:
# Section
# API Keys                      10
# Anchor Entity                 15
# Collection Zones               8
# Dark theme                     2
# Events - Smartview Display     1
# Groups                        10
# Header Area                    1
# Help UI                        2
# Light theme                    1
# Login                          8
# Quick search                   5
# Related Entities               6
# Search                         8
# SmartView-Sections            20
# Test Cases                     1
# User Management               16
# Name: Title, dtype: int64

# %%
section_grouped.groups
# Out:
# {'API Keys': Int64Index([78, 79, 80, 81, 82, 83, 84, 85, 86, 87], dtype='int64'),
#  'Anchor Entity': Int64Index([58, 59, 60, 61, 62, 63, 64, 65, 66, 67, 68, 69, 70, 71, 72], dtype='int64'),
#  'Collection Zones': Int64Index([0, 1, 2, 3, 4, 5, 6, 7], dtype='int64'),
#  'Dark theme': Int64Index([74, 75], dtype='int64'),
#  'Events - Smartview Display': Int64Index([77], dtype='int64'),
#  'Groups': Int64Index([104, 105, 106, 107, 108, 109, 110, 111, 112, 113], dtype='int64'),
#  'Header Area': Int64Index([51], dtype='int64'),
#  'Help UI': Int64Index([8, 9], dtype='int64'),
#  'Light theme': Int64Index([76], dtype='int64'),
#  'Login': Int64Index([10, 11, 12, 13, 14, 15, 16, 17], dtype='int64'),
#  'Quick search': Int64Index([26, 27, 28, 29, 30], dtype='int64'),
#  'Related Entities': Int64Index([52, 53, 54, 55, 56, 57], dtype='int64'),
#  'Search': Int64Index([18, 19, 20, 21, 22, 23, 24, 25], dtype='int64'),
# ...

# %%
section_grouped.describe()
# Out:
#                            Title         \
#                            count unique
# Section
# API Keys                      10     10
# Anchor Entity                 15     15
# Collection Zones               8      8
# Dark theme                     2      2
# Events - Smartview Display     1      1
# Groups                        10      9
# Header Area                    1      1
# Help UI                        2      2
# Light theme                    1      1
# Login                          8      8
# Quick search                   5      5
# Related Entities               6      6
# Search                         8      8
# SmartView-Sections            20     19
# Test Cases                     1      1
# User Management               16     16
#
#                                                                                \
#                                                                           top
# Section
# ...
